# %%
#Instalar librerías
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

# %%
#Importar librerías: pandas y numpy
import pandas as pd 
import numpy as np
import io

#Leer el contenido del archivo
#df = pd.read_excel('Inmuebles.xlsx', index_col=2) 
df = pd.read_excel('Inmuebles.xlsx') 
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3337 entries, 0 to 3336
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Referencia    3337 non-null   int64
#  1   Fecha Alta    3337 non-null   datetime64[ns]
#  2   Tipo          3337 non-null   object
#  3   Operación     3337 non-null   object
#  4   Provincia     3337 non-null   object
#  5   Superficie    3337 non-null   int64
#  6   Precio Venta  3337 non-null   int64
#  7   Fecha Venta   2759 non-null   datetime64[ns]
#  8   Vendedor      2759 non-null   object
# dtypes: datetime64[ns](2), int64(3), object(4)
# memory usage: 234.8+ KB
#       Referencia Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida         291
# 1              2 2004-01-01       Local     Venta     Girona         199
# 2              3 2004-01-01     Oficina  Alquiler     Girona          82
# ...

# %%
#FILTROS BASICOS PARA VARIABLES CUALITATIVAS
#Conocer las operaciones de la provincia de Barcelona
#Filtro por objeto
filtro1=df[df["Provincia"] == "Barcelona"]
filtro1
# Out:
#       Referencia Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 12            13 2004-01-04     Parking     Venta  Barcelona         300
# 17            18 2004-01-06       Suelo     Venta  Barcelona         283
# 19            20 2004-01-08     Oficina  Alquiler  Barcelona         148
# 20            21 2004-01-09  Industrial     Venta  Barcelona         228
# 24            25 2004-01-10     Oficina  Alquiler  Barcelona         124
# ...          ...        ...         ...       ...        ...         ...
# 3325        3326 2007-04-25  Industrial  Alquiler  Barcelona         296
# 3326        3327 2007-04-25       Suelo  Alquiler  Barcelona         161
# 3328        3329 2007-04-26        Piso     Venta  Barcelona         264
# 3329        3330 2007-04-27     Parking     Venta  Barcelona          88
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona          88
#
#       Precio Venta Fecha Venta Vendedor
# 12         2937300  2004-11-04    Jesús
# ...

# %%
#Convertir este primer filtro a CSV
filtro1.to_csv("filtro1.csv")

# %%
#Filtro por filas
#filtro2=df.iloc[500:600,: ] #Filas consecutivas
filtro2=df.iloc[ [1050, 2050, 3050] , : ]  #filas no consecutivas 
filtro2
# Out:
#       Referencia Fecha Alta     Tipo Operación  Provincia  Superficie  \
# 1050        1051 2005-01-12  Parking     Venta     Lleida         246
# 2050        2051 2006-01-11  Parking     Venta  Tarragona         130
# 3050        3051 2007-01-11     Casa     Venta  Barcelona         259
#
#       Precio Venta Fecha Venta Vendedor
# 1050       1940448  2005-10-08    Pedro
# 2050       1275560  2006-11-13    María
# 3050       1369333         NaT      NaN

# %%
#Convertir el segundo filtro a CSV
filtro2.to_csv("filtro2.csv")

# %%
#Filtro por columnas
filtro3=df.iloc[ : , 3:6] #columnas consecutivas
#filtro3=df.iloc[ : , [3,6,8]]  #columnas no consecutivas 
filtro3
# Out:
#      Operación  Provincia  Superficie
# 0     Alquiler     Lleida         291
# 1        Venta     Girona         199
# 2     Alquiler     Girona          82
# 3     Alquiler     Girona         285
# 4        Venta  Tarragona         152
# ...        ...        ...         ...
# 3332  Alquiler     Lleida         221
# 3333  Alquiler     Girona          55
# 3334     Venta  Tarragona          78
# 3335  Alquiler  Barcelona          88
# 3336     Venta     Lleida         254
#
# [3337 rows x 3 columns]

# %%
#Convertir el tercer filtro a CSV
filtro3.to_csv("filtro3.csv")

# %%
#Filtro de filas vs columnas 
#Este filtro permite conocer los precios de venta de todos los locales y oficinas registrados en la base de datos
filtro4=df.loc[["Local","Oficina"], ["Precio Venta"]]
filtro4
# Out:
#          Precio Venta
# Tipo
# Local         1945424
# Local          664700
# Local          549780
# Local          659330
# Local          939072
# ...               ...
# Oficina        394250
# Oficina        293172
# Oficina        807432
# Oficina        463424
# Oficina       1031320
#
# [943 rows x 1 columns]

# %%
#Convertir el cuarto filtro a CSV
filtro4.to_csv("filtro4.csv")

# %%
#Filtro por cabecera
filtro5=df.head()
filtro5
# Out:
#    Referencia Fecha Alta     Tipo Operación  Provincia  Superficie  \
# 0           1 2004-01-01  Parking  Alquiler     Lleida         291
# 1           2 2004-01-01    Local     Venta     Girona         199
# 2           3 2004-01-01  Oficina  Alquiler     Girona          82
# 3           4 2004-01-02  Parking  Alquiler     Girona         285
# 4           5 2004-01-02    Suelo     Venta  Tarragona         152
#
#    Precio Venta Fecha Venta Vendedor
# 0       2133903  2004-06-19   Carmen
# 1       1945424  2004-04-19    Pedro
# 2        712416  2004-11-08  Joaquín
# 3       1815450  2004-04-27    Jesús
# 4       1138024  2004-07-10    María

# %%
#Convertir el quinto filtro a CSV
filtro5.to_csv("filtro5.csv")

# %%
#Filtro por comparacion
filtro6=df[df["Precio Venta"] > 2900000]
filtro6
# Out:
#       Referencia Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 12            13 2004-01-04     Parking     Venta  Barcelona         300
# 872          873 2004-11-09  Industrial  Alquiler     Lleida         295
# 2653        2654 2006-08-13        Piso  Alquiler     Girona         297
# 2696        2697 2006-08-31     Oficina     Venta  Barcelona         298
# 3125        3126 2007-02-10     Oficina     Venta  Tarragona         297
# 3267        3268 2007-04-01  Industrial  Alquiler  Barcelona         300
# 3288        3289 2007-04-09     Parking     Venta     Lleida         296
#
#       Precio Venta Fecha Venta Vendedor
# 12         2937300  2004-11-04    Jesús
# 872        2923155  2005-05-06    Luisa
# 2653       2909412         NaT      NaN
# 2696       2977318         NaT      NaN
# 3125       2902284         NaT      NaN
# 3267       2908500         NaT      NaN
# 3288       2914416         NaT      NaN

# %%
#Convertir el sexto filtro a CSV
filtro6.to_csv("filtro6.csv")

# %%
#FILTROS BASICOS CON CONETORES LOGICOS
#Filtro Y
filtro7=df[(df["Superficie"] >= 290) & (df["Tipo"] == "Casa")]
filtro7
# Out:
#       Referencia Fecha Alta  Tipo Operación  Provincia  Superficie  \
# 290          291 2004-04-21  Casa  Alquiler  Tarragona         295
# 303          304 2004-04-26  Casa  Alquiler  Barcelona         298
# 610          611 2004-08-11  Casa     Venta  Barcelona         294
# 759          760 2004-09-26  Casa  Alquiler  Barcelona         299
# 1466        1467 2005-06-09  Casa     Venta     Lleida         299
# 1560        1561 2005-07-15  Casa  Alquiler  Barcelona         291
# 1742        1743 2005-09-17  Casa     Venta     Girona         292
# 2375        2376 2006-05-01  Casa  Alquiler  Tarragona         296
# 2386        2387 2006-05-04  Casa     Venta     Girona         294
# 2389        2390 2006-05-05  Casa     Venta     Lleida         290
# 2612        2613 2006-07-28  Casa     Venta  Barcelona         294
# 2708        2709 2006-09-06  Casa  Alquiler     Girona         291
# 2778        2779 2006-10-04  Casa     Venta     Girona         295
# ...

# %%
#Convertir el séptimo filtro a CSV
filtro7.to_csv("filtro7.csv")

# %%
#Filtro o 
filtro8=df[(df["Superficie"] > 250) | (df["Provincia"] == "Girona")]
filtro8
# Out:
#       Referencia Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida         291
# 1              2 2004-01-01       Local     Venta     Girona         199
# 2              3 2004-01-01     Oficina  Alquiler     Girona          82
# 3              4 2004-01-02     Parking  Alquiler     Girona         285
# 5              6 2004-01-03  Industrial  Alquiler     Girona         131
# ...          ...        ...         ...       ...        ...         ...
# 3325        3326 2007-04-25  Industrial  Alquiler  Barcelona         296
# 3328        3329 2007-04-26        Piso     Venta  Barcelona         264
# 3330        3331 2007-04-27       Local     Venta     Girona         110
# 3333        3334 2007-04-29        Piso  Alquiler     Girona          55
# 3336        3337 2007-04-30     Parking     Venta     Lleida         254
#
#       Precio Venta Fecha Venta Vendedor
# 0          2133903  2004-06-19   Carmen
# ...

# %%
#Convertir el octavo filtro a CSV
filtro8.to_csv("filtro8.csv")

# %%
#Filtro not
filtro9=df[~(df["Operación"] == "Venta")]
filtro9
# Out:
#       Referencia Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida         291
# 2              3 2004-01-01     Oficina  Alquiler     Girona          82
# 3              4 2004-01-02     Parking  Alquiler     Girona         285
# 5              6 2004-01-03  Industrial  Alquiler     Girona         131
# 6              7 2004-01-03     Parking  Alquiler  Tarragona          69
# ...          ...        ...         ...       ...        ...         ...
# 3325        3326 2007-04-25  Industrial  Alquiler  Barcelona         296
# 3326        3327 2007-04-25       Suelo  Alquiler  Barcelona         161
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida         221
# 3333        3334 2007-04-29        Piso  Alquiler     Girona          55
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona          88
#
#       Precio Venta Fecha Venta Vendedor
# 0          2133903  2004-06-19   Carmen
# ...

# %%
#Convertir el noveno filtro a CSV
filtro9.to_csv("filtro9.csv")
